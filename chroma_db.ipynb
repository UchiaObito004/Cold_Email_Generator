# %%
import chromadb
client=chromadb.Client()
collection=client.create_collection("my_collection")

# %%
collection.add(
    documents=['this document is aboout new york',
               "this document is about new delhi"
               ],
    ids=['id1','id2']
    
)
# Out:
# /Users/parivat/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz: 100%|██████████| 79.3M/79.3M [00:42<00:00, 1.95MiB/s]

# %%
all_docs=collection.get()

# %%
docs=collection.get(ids=['id1'])

# %%
results=collection.query(
    query_texts=['query is about chole bhature ?'],
    n_results=2
)

# %%
results
# Out:
# {'ids': [['id2', 'id1']],
#  'embeddings': None,
#  'documents': [['this document is about new delhi',
#    'this document is aboout new york']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[None, None]],
#  'distances': [[1.5039913654327393, 1.6556004285812378]]}
